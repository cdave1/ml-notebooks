# %% [markdown]
# Load a pre-trained model and test it against inputs

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from common import NeuralNetwork
import matplotlib.pyplot as plt

model = NeuralNetwork()
model.load_state_dict(torch.load("model.pth"))


test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

classes = [
    "tshirt",
    "trousers",
    "pullover",
    "dress",
    "coat",
    "sandal",
    "shirt",
    "sneaker",
    "bag",
    "ankle boot"
]

model.eval()
with torch.no_grad():
    for i in range(50):
        x, y = test_data[i][0], test_data[i][1]
        pred = model(x)
        predicted, actual = classes[pred[0].argmax(0)], classes[y]
        print(f'Predicted: "{predicted}", Actual: "{actual}"')
        plt.imshow(x.reshape(28,28), cmap="gray")
        plt.show()
# Out:
# Predicted: "ankle boot", Actual: "ankle boot"
# Predicted: "pullover", Actual: "pullover"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "shirt", Actual: "shirt"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "coat", Actual: "coat"
# Predicted: "shirt", Actual: "shirt"
# Predicted: "sandal", Actual: "sandal"
# Predicted: "sneaker", Actual: "sneaker"
# Predicted: "coat", Actual: "coat"
# Predicted: "sandal", Actual: "sandal"
# Predicted: "sandal", Actual: "sneaker"
# Predicted: "dress", Actual: "dress"
# Predicted: "coat", Actual: "coat"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "pullover", Actual: "pullover"
# Predicted: "shirt", Actual: "coat"
# Predicted: "bag", Actual: "bag"
# Predicted: "tshirt", Actual: "tshirt"
# Predicted: "tshirt", Actual: "pullover"
# Predicted: "sneaker", Actual: "sandal"
# Predicted: "sneaker", Actual: "sneaker"
# Predicted: "sneaker", Actual: "ankle boot"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "pullover", Actual: "coat"
# Predicted: "coat", Actual: "shirt"
# Predicted: "dress", Actual: "tshirt"
# Predicted: "ankle boot", Actual: "ankle boot"
# Predicted: "dress", Actual: "dress"
# Predicted: "bag", Actual: "bag"
# Predicted: "bag", Actual: "bag"
# Predicted: "dress", Actual: "dress"
# Predicted: "dress", Actual: "dress"
# Predicted: "bag", Actual: "bag"
# Predicted: "tshirt", Actual: "tshirt"
# Predicted: "sneaker", Actual: "sneaker"
# Predicted: "sandal", Actual: "sandal"
# Predicted: "sneaker", Actual: "sneaker"
# Predicted: "ankle boot", Actual: "ankle boot"
# Predicted: "tshirt", Actual: "shirt"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "dress", Actual: "dress"
# Predicted: "ankle boot", Actual: "sneaker"
# Predicted: "shirt", Actual: "shirt"
# Predicted: "sandal", Actual: "sneaker"
# Predicted: "pullover", Actual: "pullover"
# Predicted: "trousers", Actual: "trousers"
# Predicted: "coat", Actual: "pullover"
# Predicted: "shirt", Actual: "pullover"
